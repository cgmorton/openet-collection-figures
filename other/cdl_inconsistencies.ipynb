# %%
import calendar
from datetime import timedelta, datetime
import pprint

import ee
from IPython.display import Image, display
import ipyplot
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import openet.core

ee.Initialize()

# %%
cdl_img = ee.Image('USDA/NASS/CDL/2014').select('cropland')
cdl_properties =  ee.Image('USDA/NASS/CDL/2014').toDictionary()

image_size = 500

region = [-120.0, 25, -70, 50]

# %%
# region = [-124.0, 25, -66, 50]
# image_size = 700
# urls = []
# labels = []
# # for year in range(2008, 2025):
# for year in range(2008, 2011):
#     image_url = (
#         ee.Image(f'USDA/NASS/CDL/{year}').select('cropland')
#         .visualize().getThumbURL({'region': region, 'dimensions': image_size})
#     )
#     urls.append(image_url)
#     labels.append(f'Cropland Data Layer {year}')
    
# ipyplot.plot_images(urls, labels=labels, show_url=False, img_width=image_size)

# %%
region = [-120.0, 26, -73, 50]
Image(
    ee.Image(f'USDA/NASS/CDL/2008').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2009').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2010').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2011').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2012').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2013').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2014').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2015').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2016').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2017').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2018').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)

# %%
Image(
    ee.Image(f'USDA/NASS/CDL/2019').select('cropland').visualize()
        .getThumbURL({'region': region, 'dimensions': image_size}), 
    embed=True, format='png'
)
