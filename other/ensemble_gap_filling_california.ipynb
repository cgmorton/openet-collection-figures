# %%
import calendar
from datetime import timedelta, datetime
import pprint

import ee
from IPython.display import Image, display
import ipyplot
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import openet.core

ee.Initialize()

# %%
filled_coll = ee.ImageCollection('projects/openet/assets/ensemble/california/cimis/monthly/v2_1_filled')

region = [-124.5, 32.5, -114, 42.1]

et_palette = [
    'DEC29B', 'E6CDA1', 'EDD9A6', 'F5E4A9', 'FFF4AD', 'C3E683', '6BCC5C', 
    '3BB369', '20998F', '1C8691', '16678A', '114982', '0B2C7A'
]
viridis = ['440154', '433982', '30678D', '218F8B', '36B677', '8ED542', 'FDE725']
et_vis = {'min': 0, 'max': 150, 'palette': et_palette}
mask_vis = {'min': 0, 'max': 3, 'palette': viridis}

dates = [f'{year:04d}-{month:02d}-01' for year in [2024] for month in range(1, 13)]
# dates = [f'{year:04d}-{month:02d}-01' for year in [2024] for month in range(1, 2)]

image_size = 500

# %%
urls = []
labels = []
for date in dates:
    image_url = (
        filled_coll.filterDate(ee.Date(date), ee.Date(date).advance(1, 'month'))
        .select(['et_unfilled']).sum()
        .visualize(**et_vis).getThumbURL({'region': region, 'dimensions': image_size})
    )
    urls.append(image_url)
    labels.append(f'Unfilled Ensemble ET {date}')
        
ipyplot.plot_images(urls, labels=labels, show_url=False, img_width=image_size)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-A7kmvzFxxw4EN23Qx9RM5j {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-A7kmvzFxxw4EN23Qx9RM5j {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-A7kmvzFxxw4EN23Qx9RM5j {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-A7kmvzFxxw4EN23Qx9RM5j:checked ~ #ipyplot-html-viewer-textarea-A7kmvzFxxw4EN23Qx9RM5j {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-A7kmvzFxxw4EN23Qx9RM5j:checked + #ipyplot-html-viewer-label-A7kmvzFxxw4EN23Qx9RM5j:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-A7kmvzFxxw4EN23Qx9RM5j">
#         <label id="ipyplot-html-viewer-label-A7kmvzFxxw4EN23Qx9RM5j" for="ipyplot-html-viewer-toggle-A7kmvzFxxw4EN23Qx9RM5j">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-A7kmvzFxxw4EN23Qx9RM5j" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-dxUSyLHNj4vTgymbqPCvkr {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr {
#             width: 500px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr {
#             width: 500px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr img {
#             width: 500px;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-dxUSyLHNj4vTgymbqPCvkr">
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-jRUWE7rrMNX4dWEiRXc3AF" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-01-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/bae0439661c8b83e754869429563cc28-3daf56bca4733d525afd96c03a310b35:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-jRUWE7rrMNX4dWEiRXc3AF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-KXcCoPRqDf7cWSaPcHUbNz" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-02-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/f7972ab53b706772059ea94ed107585c-deda3eca6c1482900b40283ed68d2c2c:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-KXcCoPRqDf7cWSaPcHUbNz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-6BdL5hYe4V83f9JLs7hbEe" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-03-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/6654188761f2bf0b1f03a1777e1f0c84-f549e91d8fe443ac8566b5c63784219b:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-6BdL5hYe4V83f9JLs7hbEe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-ksXKMvE6xRxqujsBhkP3FE" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-04-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/afd11838fa7668eff2d7c665081449f0-3abf36e2d09bebdc60518b3c4ab57e36:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-ksXKMvE6xRxqujsBhkP3FE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-AYCHSn4VRvCaU94LzaVtXG" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-05-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/2ffe65cda95b0558c3bae675ec63b008-8155d57caccfda2101a55c090a2faf93:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-AYCHSn4VRvCaU94LzaVtXG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-nKEPaJ6FisFH6L9ostUv4S" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-06-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/03da23e8e2bbd66499eef2c82afa2477-9084df9355ea8ef00ca473b94942ec58:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-nKEPa
#         <style>
#         #ipyplot-imgs-container-div-dxUSyLHNj4vTgymbqPCvkr {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr {
#             width: 500px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr {
#             width: 500px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr img {
#             width: 500px;
#         }
#
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-dxUSyLHNj4vTgymbqPCvkr">
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-jRUWE7rrMNX4dWEiRXc3AF" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-01-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/bae0439661c8b83e754869429563cc28-3daf56bca4733d525afd96c03a310b35:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-jRUWE7rrMNX4dWEiRXc3AF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-KXcCoPRqDf7cWSaPcHUbNz" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-02-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/f7972ab53b706772059ea94ed107585c-deda3eca6c1482900b40283ed68d2c2c:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-KXcCoPRqDf7cWSaPcHUbNz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-6BdL5hYe4V83f9JLs7hbEe" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-03-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/6654188761f2bf0b1f03a1777e1f0c84-f549e91d8fe443ac8566b5c63784219b:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-6BdL5hYe4V83f9JLs7hbEe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-ksXKMvE6xRxqujsBhkP3FE" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-04-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/afd11838fa7668eff2d7c665081449f0-3abf36e2d09bebdc60518b3c4ab57e36:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-ksXKMvE6xRxqujsBhkP3FE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-AYCHSn4VRvCaU94LzaVtXG" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-05-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/2ffe65cda95b0558c3bae675ec63b008-8155d57caccfda2101a55c090a2faf93:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-AYCHSn4VRvCaU94LzaVtXG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-nKEPaJ6FisFH6L9ostUv4S" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-06-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/03da23e8e2bbd66499eef2c82afa2477-9084df9355ea8ef00ca473b94942ec58:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-nKEPaJ6FisFH6L9ostUv4S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-7JfgcPTKMqFLfdY6ffufAc" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-07-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/abf2326dc482989f6815d8ef95470974-ae58e7abadb8654cfb5fd504200203ef:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-7JfgcPTKMqFLfdY6ffufAc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dxUSyLHNj4vTgymbqPCvkr">
#         <div id="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-bzSQ3WCyRa5yqXioSr9tgr" class="ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unfilled Ensemble ET 2024-08-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/74825e48a30e39285a2f6b10de21f069-48af7a25d3fb35dab9fc4274b5d52cc0:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dxUSyLHNj4vTgymbqPCvkr-bzSQ3WCyRa5yqXioSr9tgr">
#                 <span class="ipyplot-img-expand"/>

# %%
urls = []
labels = []
for date in dates:
    image_url = (
        filled_coll.filterDate(ee.Date(date), ee.Date(date).advance(1, 'month'))
        .select(['et_filled']).sum()
        .visualize(**et_vis).getThumbURL({'region': region, 'dimensions': image_size})
    )
    urls.append(image_url)
    labels.append(f'Filled Ensemble ET {date}')
        
ipyplot.plot_images(urls, labels=labels, show_url=False, img_width=image_size)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-azPxvwA3M9rBWdhhQyJdEV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-azPxvwA3M9rBWdhhQyJdEV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-azPxvwA3M9rBWdhhQyJdEV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle

#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-d2d7cQvQ6WsKeLSuXgAoFa">
#         <div id="ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa-mpjo9g48HbkQxUyiwghrJJ" class="ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Filled Ensemble ET 2024-05-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/e880510e0b3dedf466837186e873025e-c972e5e146aef0cc48bb09262e6a7367:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa-mpjo9g48HbkQxUyiwghrJJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-d2d7cQvQ6WsKeLSuXgAoFa">
#         <div id="ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa-i4c3JQezvLgZv4Hye3ncFw" class="ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Filled Ensemble ET 2024-06-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/cb34a52f2533c5af273e12ea30fa2441-e046465a130c646691d03d6aa26fe974:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa-i4c3JQezvLgZv4Hye3ncFw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-d2d7cQvQ6WsKeLSuXgAoFa">
#         <div id="ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa-M534zpqkEYqGCmdnYfLJPd" class="ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Filled Ensemble ET 2024-07-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/9f8ff7f633dcc05e7ec1406a9ed3b9ca-488d924e0eb66895fd9274ec44cb55e7:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa-M534zpqkEYqGCmdnYfLJPd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-d2d7cQvQ6WsKeLSuXgAoFa">
#         <div id="ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa-cA7q7wnyEBRDt6yXJNewp5" class="ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Filled Ensemble ET 2024-08-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/c827ce49576770a5528bf0bd5cb937b2-dce1e53f7ddaf380e65cf443f9f94b90:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d2d7cQvQ6WsKeLSuXgAoFa-cA7q7wnyEBRDt6yXJNewp5">
#                 <span class="ipyplot-img-expand"/>
#             </a>

# %%
urls = []
labels = []
for date in dates:
    image_url = (
        filled_coll.filterDate(ee.Date(date), ee.Date(date).advance(1, 'month'))
        .select(['filled_mask']).sum()
        .visualize(**mask_vis).getThumbURL({'region': region, 'dimensions': image_size})
    )
    urls.append(image_url)
    labels.append(f'Filled Ensemble Mask {date}')
        
ipyplot.plot_images(urls, labels=labels, show_url=False, img_width=image_size)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-TqZKBxd8N3h8DSwKfMbZ2M {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TqZKBxd8N3h8DSwKfMbZ2M {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TqZKBxd8N3h8DSwKfMbZ2M {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TqZKBxd8N3h8DSwKfMbZ2M:checked ~ #ipyplot-html-viewer-textarea-TqZKBxd8N3h8DSwKfMbZ2M {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TqZKBxd8N3h8DSwKfMbZ2M:checked + #ipyplot-html-viewer-label-TqZKBxd8N3h8DSwKfMbZ2M:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-TqZKBxd8N3h8DSwKfMbZ2M">
#         <label id="ipyplot-html-viewer-label-TqZKBxd8N3h8DSwKfMbZ2M" for="ipyplot-html-viewer-toggle-TqZKBxd8N3h8DSwKfMbZ2M">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-TqZKBxd8N3h8DSwKfMbZ2M" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-RDEktyM5STynkvsYVFrbNc {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-RDEktyM5STynkvsYVFrbNc {
#             width: 500px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-RDEktyM5STynkvsYVFrbNc {
#             width: 500px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RDEktyM5STynkvsYVFrbNc span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-RDEktyM5STynkvsYVFrbNc span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RDEktyM5STynkvsYVFrbNc img {
#             width: 500px;
#         }
#
#         div.ipyplot-content-div-RDEktyM5STynkvsYVFrbNc span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-RDEktyM5STynkvsYVFrbNc span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-RDEktyM5STynkvsYVFrbNc]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-RDEktyM5STynkvsYVFrbNc]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-RDEktyM5STynkvsYVFrbNc]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-RDEktyM5STynkvsYVFrbNc">
#     <div class="ipyplot-placeholder-div-RDEktyM5STynkvsYVFrbNc">
#         <div id="ipyplot-content-div-RDEktyM5STynkvsYVFrbNc-XCy89ucwxuEDkrmkfVvaXt" class="ipyplot-content-div-RDEktyM5STynkvsYVFrbNc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Filled Ensemble Mask 2024-01-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/a371708afab9a5d9415c4c1eee8e39e6-cabe2103d00954bccd39b106fcd7789f:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RDEktyM5STynkvsYVFrbNc-XCy89ucwxuEDkrmkfVvaXt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RDEktyM5STynkvsYVFrbNc">
#         <div id="ipyplot-content-div-RDEktyM5STynkvsYVFrbNc-nKsHCansZYbZ4FFNseGgkN" class="ipyplot-content-div-RDEktyM5STynkvsYVFrbNc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Filled Ensemble Mask 2024-02-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/03df37dcb667c35f49be68882e41d1c5-74b1a69da0f0f93b9a85709705e456ea:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RDEktyM5STynkvsYVFrbNc-nKsHCansZYbZ4FFNseGgkN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RDEktyM5STynkvsYVFrbNc">
#         <div id="ipyplot-content-div-RDEktyM5STynkvsYVFrbNc-8Ztvc3ddFMvmoY3GqZB84P" class="ipyplot-content-div-RDEktyM5STynkvsYVFrbNc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Filled Ensemble Mask 2024-03-01</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails