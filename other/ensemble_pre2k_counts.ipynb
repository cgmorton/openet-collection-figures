# %%
from datetime import timedelta, datetime
import pprint

import ee
from IPython.display import Image, display
import ipyplot
import matplotlib.pyplot as plt
import numpy as np
import openet.core

ee.Initialize()

# %%
monthly_coll = ee.ImageCollection('projects/openet/assets/ensemble/conus/gridmet/monthly/v2_0_pre2000')
band_name = 'et_ensemble_mad'

years = list(range(1985, 2000))

region = ee.Geometry.BBox(-125.5, 25, -85.5, 50)
#region = ee.Geometry.BBox(-125.0, 25, -86.0, 50)

image_size = 768

et_palette = ['DEC29B', 'E6CDA1', 'EDD9A6', 'F5E4A9', 'FFF4AD', 'C3E683', '6BCC5C', '3BB369', '20998F', '1C8691', '16678A', '114982', '0B2C7A']
viridis = ['440154', '433982', '30678D', '218F8B', '36B677', '8ED542', 'FDE725']
# et_vis = {min: 0, max: 150, palette: et_palette}

land_mask = ee.Image('projects/openet/assets/features/water_mask').Not()
# Apply the NLCD/NALCMS water mask (anywhere it is water, set the ocean mask 
land_mask = land_mask.where(ee.Image("USGS/NLCD_RELEASES/2020_REL/NALCMS").unmask(18).eq(18), 0)
# land_mask = land_mask.And(ee.Image("USGS/NLCD_RELEASES/2020_REL/NALCMS").unmask(18).neq(18))
# # land_mask = ee.Image('projects/openet/assets/meteorology/conus404/ancillary/land_mask')

# %%
start_date = '1990-01-01'
end_date = '1991-01-01'

image_url = (
    monthly_coll.filterDate(start_date, end_date).select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 450})
)
Image(image_url, embed=True, format='png')

# %%
for year in range(1985, 1999):
    print(year)
    image_url = (
        monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').select([band_name]).count()
        .visualize(min=0, max=12, palette=viridis)
        .getThumbURL({'region': region, 'dimensions': image_size})
    )
    ipyplot.plot_images([image_url], img_width=image_size, show_url=False)
# Out:
# 1985
#     <style>
#         #ipyplot-html-viewer-toggle-UWebcMnfFwAvJr3avV6UrF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UWebcMnfFwAvJr3avV6UrF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UWebcMnfFwAvJr3avV6UrF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UWebcMnfFwAvJr3avV6UrF:checked ~ #ipyplot-html-viewer-textarea-UWebcMnfFwAvJr3avV6UrF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UWebcMnfFwAvJr3avV6UrF:checked + #ipyplot-html-viewer-label-UWebcMnfFwAvJr3avV6UrF:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-UWebcMnfFwAvJr3avV6UrF">
#         <label id="ipyplot-html-viewer-label-UWebcMnfFwAvJr3avV6UrF" for="ipyplot-html-viewer-toggle-UWebcMnfFwAvJr3avV6UrF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-UWebcMnfFwAvJr3avV6UrF" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-3kkzRdoR4DQfDnRCYhKrCt {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3kkzRdoR4DQfDnRCYhKrCt {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3kkzRdoR4DQfDnRCYhKrCt">
#     <div class="ipyplot-placeholder-div-3kkzRdoR4DQfDnRCYhKrCt">
#         <div id="ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt-2xovSrSVjKkF2A4xjmGnsN" class="ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/b0b965d4c45077f164923e5e7885f3a3-cbbc0fe8892132611c16915cb10e633e:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt-2xovSrSVjKkF2A4xjmGnsN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-3kkzRdoR4DQfDnRCYhKrCt {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3kkzRdoR4DQfDnRCYhKrCt {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrCt]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3kkzRdoR4DQfDnRCYhKrCt">
#     <div class="ipyplot-placeholder-div-3kkzRdoR4DQfDnRCYhKrCt">
#         <div id="ipyplot-content-div-3kkzRdoR4DQfDnRCYhKrC
 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5EGWg8JBqFcnZuKfsYeHYJ {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5EGWg8JBqFcnZuKfsYeHYJ">
#     <div class="ipyplot-placeholder-div-5EGWg8JBqFcnZuKfsYeHYJ">
#         <div id="ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ-GAj7qHuv5vkG83aMCpNo5K" class="ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/828db97538b71c1f01d851905b534fe4-cd93ee4995e8d6b6fb7a53430131ba05:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ-GAj7qHuv5vkG83aMCpNo5K">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-5EGWg8JBqFcnZuKfsYeHYJ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5EGWg8JBqFcnZuKfsYeHYJ {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5EGWg8JBqFcnZuKfsYeHYJ">
#     <div class="ipyplot-placeholder-div-5EGWg8JBqFcnZuKfsYeHYJ">
#         <div id="ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ-GAj7qHuv5vkG83aMCpNo5K" class="ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/828db97538b71c1f01d851905b534fe4-cd93ee4995e8d6b6fb7a53430131ba05:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5EGWg8JBqFcnZuKfsYeHYJ-GAj7qHuv5vkG83aMCpNo5K">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 1998
#     <style>
#         #ipyplot-html-viewer-toggle-EnFYDraW7KHmjGXF38T4FK {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-EnFYDraW7KHmjGXF38T4FK {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-EnFYDraW7KHmjGXF38T4FK {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-EnFYDraW7KHmjGXF38T4FK:checked ~ #ipyplot-html-viewer-textarea-EnFYDraW7KHmjGXF38T4FK {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-EnFYDraW7KHmjGXF38T4FK:checked + #ipyplot-html-viewer-label-EnFYDraW7KHmjGXF38T4FK:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-EnFYDraW7KHmjGXF38T4FK">
#         <label id="ipyplot-html-viewer-label-EnFYDraW7KHmjGXF38T4FK" for="ipyplot-html-viewer-toggle-EnFYDraW7KHmjGXF38T4FK">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-EnFYDraW7KHmjGXF38T4FK" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-LAzChKJU4tZVYERTQj3UdW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LAzChKJU4tZVYERTQj3UdW {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LAzChKJU4tZVYERTQj3UdW">
#     <div class="ipyplot-placeholder-div-LAzChKJU4tZVYERTQj3UdW">
#         <div id="ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW-iogfo7JKXXndGsFbDocdv7" class="ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/a0b02caafdd8072cdeb6491334529cf3-fed0e00ed0ae2446fad1cff14d71a449:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW-iogfo7JKXXndGsFbDocdv7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-LAzChKJU4tZVYERTQj3UdW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LAzChKJU4tZVYERTQj3UdW {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LAzChKJU4tZVYERTQj3UdW">
#     <div class="ipyplot-placeholder-div-LAzChKJU4tZVYERTQj3UdW">
#         <div id="ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW-iogfo7JKXXndGsFbDocdv7" class="ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/a0b02caafdd8072cdeb6491334529cf3-fed0e00ed0ae2446fad1cff14d71a449:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LAzChKJU4tZVYERTQj3UdW-iogfo7JKXXndGsFbDocdv7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
# Map.addLayer(ensemble_conus_coll.select(['et_ensemble_sam']).sum().divide(months), et_vis, 'SAM CONUS ET', false);
# Map.addLayer(ensemble_conus_coll.select(['et_ensemble_mad']).sum().divide(months), et_vis, 'MAD Mean CONUS ET', true);
# //Map.addLayer(ensemble_conus_coll.select(['et_ensemble_mad_index']), {min:0, max:256}, 'MAD Index CONUS ET', false);
# Map.addLayer(ensemble_conus_coll.select(['et_ensemble_mad']).count(), {min:0, max:12, palette: viridis}, 'Month Count CONUS ET', true);
# Map.addLayer(ensemble_conus_coll.select(['et_ensemble_mad_count']).mean(), {min:0, max:6, palette: viridis}, 'Model Count CONUS ET', true);
