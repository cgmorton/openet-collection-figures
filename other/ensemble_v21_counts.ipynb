# %%
from datetime import timedelta, datetime
import pprint
import time

import ee
from IPython.display import Image, display
import ipyplot
import matplotlib.pyplot as plt
import numpy as np
import openet.core

ee.Initialize()

# %%
monthly_coll = ee.ImageCollection('projects/openet/assets/ensemble/conus/gridmet/monthly/v2_1')
band_name = 'et_ensemble_mad'

years = list(range(2000, 2026))


region = ee.Geometry.BBox(-125.5, 25, -65.5, 50)
#region = ee.Geometry.BBox(-125.5, 25, -85.5, 50)
#region = ee.Geometry.BBox(-125.0, 25, -86.0, 50)

image_size = 768

et_palette = ['DEC29B', 'E6CDA1', 'EDD9A6', 'F5E4A9', 'FFF4AD', 'C3E683', '6BCC5C', '3BB369', '20998F', '1C8691', '16678A', '114982', '0B2C7A']
viridis = ['440154', '433982', '30678D', '218F8B', '36B677', '8ED542', 'FDE725']
# et_vis = {min: 0, max: 150, palette: et_palette}

land_mask = ee.Image('projects/openet/assets/features/water_mask').Not()
# Apply the NLCD/NALCMS water mask (anywhere it is water, set the ocean mask 
land_mask = land_mask.where(ee.Image("USGS/NLCD_RELEASES/2020_REL/NALCMS").unmask(18).eq(18), 0)
# land_mask = land_mask.And(ee.Image("USGS/NLCD_RELEASES/2020_REL/NALCMS").unmask(18).neq(18))
# # land_mask = ee.Image('projects/openet/assets/meteorology/conus404/ancillary/land_mask')

# %%
start_date = '2024-01-01'
end_date = '2025-01-01'

image_url = (
    monthly_coll.filterDate(start_date, end_date).select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': ee.Geometry.BBox(-125.5, 25, -66.0, 50), 'dimensions': 900})
)
Image(image_url, embed=True, format='png')

# %%
for year in years:
    print(year)
    image_url = (
        monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').select([band_name]).count()
        .visualize(min=0, max=12, palette=viridis)
        .getThumbURL({'region': region, 'dimensions': image_size})
    ) 
    ipyplot.plot_images([image_url], img_width=image_size, show_url=False)
    time.sleep(1)
# Out:
# 2000
#     <style>
#         #ipyplot-html-viewer-toggle-2bgcCEvA4vp6XNMKeJKkW5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-2bgcCEvA4vp6XNMKeJKkW5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-2bgcCEvA4vp6XNMKeJKkW5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-2bgcCEvA4vp6XNMKeJKkW5:checked ~ #ipyplot-html-viewer-textarea-2bgcCEvA4vp6XNMKeJKkW5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-2bgcCEvA4vp6XNMKeJKkW5:checked + #ipyplot-html-viewer-label-2bgcCEvA4vp6XNMKeJKkW5:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-2bgcCEvA4vp6XNMKeJKkW5">
#         <label id="ipyplot-html-viewer-label-2bgcCEvA4vp6XNMKeJKkW5" for="ipyplot-html-viewer-toggle-2bgcCEvA4vp6XNMKeJKkW5">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-2bgcCEvA4vp6XNMKeJKkW5" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-dfqyajMSwUbBvxTyeuqXqy {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dfqyajMSwUbBvxTyeuqXqy {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-dfqyajMSwUbBvxTyeuqXqy">
#     <div class="ipyplot-placeholder-div-dfqyajMSwUbBvxTyeuqXqy">
#         <div id="ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy-YLyTeVuxQUqCk4jPZ9DWNv" class="ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/d05cedd1e13fb93294705f84dba79a5a-73568bea97f92aa2fc1e5a546abcea9d:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dfqyajMSwUbBvxTyeuqXqy-YLyTeVuxQUqCk4jPZ9DWNv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div
ipyplot-content-div-M3MZAtgiCPNsaWXPivapEh">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/0660a66ce623974276279e5d9aab8f1a-c00f274a2fcd29fee81affe2b27318ae:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-M3MZAtgiCPNsaWXPivapEh-A8u3iVu3DsnfsaFaRaNm7Y">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 2006
#     <style>
#         #ipyplot-html-viewer-toggle-8rQWQEf5b2kw8NdnWjDmv3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-8rQWQEf5b2kw8NdnWjDmv3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-8rQWQEf5b2kw8NdnWjDmv3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-8rQWQEf5b2kw8NdnWjDmv3:checked ~ #ipyplot-html-viewer-textarea-8rQWQEf5b2kw8NdnWjDmv3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-8rQWQEf5b2kw8NdnWjDmv3:checked + #ipyplot-html-viewer-label-8rQWQEf5b2kw8NdnWjDmv3:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-8rQWQEf5b2kw8NdnWjDmv3">
#         <label id="ipyplot-html-viewer-label-8rQWQEf5b2kw8NdnWjDmv3" for="ipyplot-html-viewer-toggle-8rQWQEf5b2kw8NdnWjDmv3">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-8rQWQEf5b2kw8NdnWjDmv3" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-FL5Gq83f2bchYXaxFwZwZB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FL5Gq83f2bchYXaxFwZwZB {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FL5Gq83f2bchYXaxFwZwZB">
#     <div class="ipyplot-placeholder-div-FL5Gq83f2bchYXaxFwZwZB">
#         <div id="ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB-7xN4Wt5kW3En933PvF4pKM" class="ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/fbfe9d81aad4900aa1fc5894eed7c262-e71c59ae59e1cd5c8c8eef4910d5ce25:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB-7xN4Wt5kW3En933PvF4pKM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-FL5Gq83f2bchYXaxFwZwZB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FL5Gq83f2bchYXaxFwZwZB {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FL5Gq83f2bchYXaxFwZwZB {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
# ...
#         }
#
#         div.ipyplot-content-div-WQkNxqJaHv5nx9ttCj8Coy img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-WQkNxqJaHv5nx9ttCj8Coy span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WQkNxqJaHv5nx9ttCj8Coy span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WQkNxqJaHv5nx9ttCj8Coy]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WQkNxqJaHv5nx9ttCj8Coy]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WQkNxqJaHv5nx9ttCj8Coy]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WQkNxqJaHv5nx9ttCj8Coy">
#     <div class="ipyplot-placeholder-div-WQkNxqJaHv5nx9ttCj8Coy">
#         <div id="ipyplot-content-div-WQkNxqJaHv5nx9ttCj8Coy-TNDKnq2qHEocfNUeDvYE2e" class="ipyplot-content-div-WQkNxqJaHv5nx9ttCj8Coy">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/9ef5fa5fe8202b762375f5d656b28bd5-2651a73a4904413a94763673f5b83fc3:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WQkNxqJaHv5nx9ttCj8Coy-TNDKnq2qHEocfNUeDvYE2e">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 2024
#     <style>
#         #ipyplot-html-viewer-toggle-jmbfbQehzU74MiBzabGVvG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jmbfbQehzU74MiBzabGVvG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jmbfbQehzU74MiBzabGVvG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jmbfbQehzU74MiBzabGVvG:checked ~ #ipyplot-html-viewer-textarea-jmbfbQehzU74MiBzabGVvG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jmbfbQehzU74MiBzabGVvG:checked + #ipyplot-html-viewer-label-jmbfbQehzU74MiBzabGVvG:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jmbfbQehzU74MiBzabGVvG">
#         <label id="ipyplot-html-viewer-label-jmbfbQehzU74MiBzabGVvG" for="ipyplot-html-viewer-toggle-jmbfbQehzU74MiBzabGVvG">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jmbfbQehzU74MiBzabGVvG" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-fKWJ8zRgKAx5MBa8XGYRsh {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fKWJ8zRgKAx5MBa8XGYRsh {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fKWJ8zRgKAx5MBa8XGYRsh">
#     <div class="ipyplot-placeholder-div-fKWJ8zRgKAx5MBa8XGYRsh">
#         <div id="ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh-49uxWJvDusC6tKn2rVJ7jK" class="ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/ee2b197893e79635857ddbec9f17a435-9b9a24b0d6a338afcadc78e31d836088:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh-49uxWJvDusC6tKn2rVJ7jK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-fKWJ8zRgKAx5MBa8XGYRsh {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fKWJ8zRgKAx5MBa8XGYRsh {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fKWJ8zRgKAx5MBa8XGYRsh">
#     <div class="ipyplot-placeholder-div-fKWJ8zRgKAx5MBa8XGYRsh">
#         <div id="ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh-49uxWJvDusC6tKn2rVJ7jK" class="ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/ee2b197893e79635857ddbec9f17a435-9b9a24b0d6a338afcadc78e31d836088:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fKWJ8zRgKAx5MBa8XGYRsh-49uxWJvDusC6tKn2rVJ7jK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 2025
#     <style>
#         #ipyplot-html-viewer-toggle-5SpE28RZ53WYTWTE7GcPiN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5SpE28RZ53WYTWTE7GcPiN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5SpE28RZ53WYTWTE7GcPiN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5SpE28RZ53WYTWTE7GcPiN:checked ~ #ipyplot-html-viewer-textarea-5SpE28RZ53WYTWTE7GcPiN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5SpE28RZ53WYTWTE7GcPiN:checked + #ipyplot-html-viewer-label-5SpE28RZ53WYTWTE7GcPiN:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-5SpE28RZ53WYTWTE7GcPiN">
#         <label id="ipyplot-html-viewer-label-5SpE28RZ53WYTWTE7GcPiN" for="ipyplot-html-viewer-toggle-5SpE28RZ53WYTWTE7GcPiN">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-5SpE28RZ53WYTWTE7GcPiN" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-FATAWZ6s5fZwbXux2syJWj {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FATAWZ6s5fZwbXux2syJWj {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FATAWZ6s5fZwbXux2syJWj">
#     <div class="ipyplot-placeholder-div-FATAWZ6s5fZwbXux2syJWj">
#         <div id="ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj-E8Yek5VJpUj5ywf9JQXZWr" class="ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/3458132cdc8f27e1a362b6151833b770-38bd44c6ab2ed1caa3c7bdae8e1fea78:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj-E8Yek5VJpUj5ywf9JQXZWr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-FATAWZ6s5fZwbXux2syJWj {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FATAWZ6s5fZwbXux2syJWj {
#             width: 768px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj {
#             width: 768px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj img {
#             width: 768px;
#         }
#
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FATAWZ6s5fZwbXux2syJWj">
#     <div class="ipyplot-placeholder-div-FATAWZ6s5fZwbXux2syJWj">
#         <div id="ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj-E8Yek5VJpUj5ywf9JQXZWr" class="ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/3458132cdc8f27e1a362b6151833b770-38bd44c6ab2ed1caa3c7bdae8e1fea78:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FATAWZ6s5fZwbXux2syJWj-E8Yek5VJpUj5ywf9JQXZWr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
# Map.addLayer(ensemble_conus_coll.select(['et_ensemble_sam']).sum().divide(months), et_vis, 'SAM CONUS ET', false);
# Map.addLayer(ensemble_conus_coll.select(['et_ensemble_mad']).sum().divide(months), et_vis, 'MAD Mean CONUS ET', true);
# //Map.addLayer(ensemble_conus_coll.select(['et_ensemble_mad_index']), {min:0, max:256}, 'MAD Index CONUS ET', false);
# Map.addLayer(ensemble_conus_coll.select(['et_ensemble_mad']).count(), {min:0, max:12, palette: viridis}, 'Month Count CONUS ET', true);
# Map.addLayer(ensemble_conus_coll.select(['et_ensemble_mad_count']).mean(), {min:0, max:6, palette: viridis}, 'Model Count CONUS ET', true);
