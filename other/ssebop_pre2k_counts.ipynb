# %%
from datetime import timedelta, datetime
import pprint

import ee
from IPython.display import Image, display
import ipyplot
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import openet.core

ee.Initialize()

# %%
monthly_coll = ee.ImageCollection('projects/openet/assets/ssebop/conus/gridmet/monthly/v2_0_pre2000')
band_name = 'et'

years = list(range(1985, 2000))

region = ee.Geometry.BBox(-125.5, 25, -85.5, 50)
#region = ee.Geometry.BBox(-125.0, 25, -86.0, 50)

image_size = 512

et_palette = ['DEC29B', 'E6CDA1', 'EDD9A6', 'F5E4A9', 'FFF4AD', 'C3E683', '6BCC5C', '3BB369', '20998F', '1C8691', '16678A', '114982', '0B2C7A']
viridis = ['440154', '433982', '30678D', '218F8B', '36B677', '8ED542', 'FDE725']
# et_vis = {min: 0, max: 150, palette: et_palette}

land_mask = ee.Image('projects/openet/assets/features/water_mask').Not()
# Apply the NLCD/NALCMS water mask (anywhere it is water, set the ocean mask 
land_mask = land_mask.where(ee.Image("USGS/NLCD_RELEASES/2020_REL/NALCMS").unmask(18).eq(18), 0)
# land_mask = land_mask.And(ee.Image("USGS/NLCD_RELEASES/2020_REL/NALCMS").unmask(18).neq(18))
# # land_mask = ee.Image('projects/openet/assets/meteorology/conus404/ancillary/land_mask')

# %%
def mask_count_zero(img):
    mask_img = img.select(['count']).gt(0)
    return img.updateMask(mask_img)

# %%
year = 1989

image_url = (
    monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 450})
)
Image(image_url, embed=True, format='png')

# %%
year = 1989

image_url = (
    monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').map(mask_count_zero).select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 450})
)
Image(image_url, embed=True, format='png')

# %%
year = 1998

image_url = (
    monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 450})
)
Image(image_url, embed=True, format='png')  
#ipyplot.plot_images([image_url], img_width=image_size)

# %%
year = 1998

image_url = (
    monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').map(mask_count_zero).select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 450})
)
Image(image_url, embed=True, format='png')  
#ipyplot.plot_images([image_url], img_width=image_size)

# %%
for year in years:
    print(year)
    with_count_zero_url = (
        monthly_coll
        .filterDate(f'{year}-01-01', f'{year+1}-01-01')
        .select([band_name]).count()
        .visualize(min=0, max=12, palette=viridis)
        .getThumbURL({'region': region, 'dimensions': image_size})
    )
    no_count_zero_url = (
        monthly_coll
        .filterDate(f'{year}-01-01', f'{year+1}-01-01')
        .map(mask_count_zero)
        .select([band_name]).count()
        .visualize(min=0, max=12, palette=viridis)
        .getThumbURL({'region': region, 'dimensions': image_size})
    )
    ipyplot.plot_images([with_count_zero_url, no_count_zero_url], labels=['With Count Zero Months', 'Without Count Zero Months'], show_url=False, img_width=image_size)
    #break
# Out:
# 1985
#     <style>
#         #ipyplot-html-viewer-toggle-H7mw9KWccfzkxctGNEwCFY {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-H7mw9KWccfzkxctGNEwCFY {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-H7mw9KWccfzkxctGNEwCFY {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-H7mw9KWccfzkxctGNEwCFY:checked ~ #ipyplot-html-viewer-textarea-H7mw9KWccfzkxctGNEwCFY {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-H7mw9KWccfzkxctGNEwCFY:checked + #ipyplot-html-viewer-label-H7mw9KWccfzkxctGNEwCFY:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-H7mw9KWccfzkxctGNEwCFY">
#         <label id="ipyplot-html-viewer-label-H7mw9KWccfzkxctGNEwCFY" for="ipyplot-html-viewer-toggle-H7mw9KWccfzkxctGNEwCFY">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-H7mw9KWccfzkxctGNEwCFY" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-dpcrVuxju8znVQdDrSVErn {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dpcrVuxju8znVQdDrSVErn {
#             width: 512px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn {
#             width: 512px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn img {
#             width: 512px;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dpcrVuxju8znVQdDrSVErn]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dpcrVuxju8znVQdDrSVErn]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dpcrVuxju8znVQdDrSVErn]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-dpcrVuxju8znVQdDrSVErn">
#     <div class="ipyplot-placeholder-div-dpcrVuxju8znVQdDrSVErn">
#         <div id="ipyplot-content-div-dpcrVuxju8znVQdDrSVErn-izqSTwX5gnjjR6mRGbdtQN" class="ipyplot-content-div-dpcrVuxju8znVQdDrSVErn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">With Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/af670127a78592adac4e6d019dc537c6-5372a3f832fe6c2bea07084b220250f6:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dpcrVuxju8znVQdDrSVErn-izqSTwX5gnjjR6mRGbdtQN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dpcrVuxju8znVQdDrSVErn">
#         <div id="ipyplot-content-div-dpcrVuxju8znVQdDrSVErn-S3bAr36JtygpGEUmuuTqfq" class="ipyplot-content-div-dpcrVuxju8znVQdDrSVErn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Without Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/793bc06a2ca656bb062f22bb1cdb7b16-343770222690d34afd9c406f58d58e9f:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dpcrVuxju8znVQdDrSVErn-S3bAr36JtygpGEUmuuTqfq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-dpcrVuxju8znVQdDrSVErn {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dpcrVuxju8znVQdDrSVErn {
#             width: 512px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn {
#             width: 512px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn img {
#             width: 512px;
#         }
#
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dpcrVuxju8znVQdDrSVErn span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dpcrVuxju8znVQdDrSVErn]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dpcrVuxju8znVQdDrSVErn]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dpcrVuxju8znVQdDrSVErn]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-dpcrVuxju8znVQdDrSVErn">
#     <div class="ipyplot-placeholder-div-dpcrVuxju8znVQdDrSVErn">
#         <div id="ipyplot-content-div-dpcrVuxju8znVQdDrSVErn-izqSTwX5gnjjR6mRGbdtQN" class="ipyplot-content-div-dpcrVuxju8znVQdDrSVErn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">With Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/af670127a78592adac4e6d019dc537c6-5372a3f832fe6c2bea07084b220250f6:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dpcrVuxju8znVQdDrSVErn-izqSTwX5gnjjR6mRGbdtQN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dpcrVuxju8znVQdDrSVErn">
#         <div id="ipyplot-content-div-dpcrVuxju8znVQdDrSVErn-S3bAr36JtygpGEUmuuTqfq" class="ipyplot-content-div-dpcrVuxju8znVQdDrSVErn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Without Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/793bc06a2ca656bb062f22bb1cdb7b16-343770222690d34afd9c406f58d58e9f:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dpcrVuxju8znVQdDrSVErn-S3bAr36JtygpGEUmuuTqfq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 1986
#     <style>
#         #ipyplot-html-viewer-toggle-CoYGaUgB5nWd3YNv3NwujS {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CoYGaUgB5nWd3YNv3NwujS {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CoYGaUgB5nWd3YNv3NwujS {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CoYGaUgB5nWd3YNv3NwujS:checked ~ #ipyplot-html-viewer-textarea-CoYGaUgB5nWd3YNv3NwujS {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CoYGaUgB5nWd3YNv3NwujS:checked + #ipyplot-html-viewer-label-CoYGaUgB5nWd3YNv3NwujS:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-CoYGaUgB5nWd3YNv3NwujS">
#         <label id="ipyplot-html-viewer-label-CoYGaUgB5nWd3YNv3NwujS" for="ipyplot-html-viewer-toggle-CoYGaUgB5nWd3YNv3NwujS">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-CoYGaUgB5nWd3YNv3NwujS" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-kCCA6PwDVu4AvJ9HCYKTcW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kCCA6PwDVu4AvJ9HCYKTcW {
#             width: 512px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW {
#             width: 512px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW img {
#             width: 512px;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kCCA6PwDVu4AvJ9HCYKTcW">
#     <div class="ipyplot-placeholder-div-kCCA6PwDVu4AvJ9HCYKTcW">
#         <div id="ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW-bBHoVZ6JasUiyfqjoHviZK" class="ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">With Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/85e7f0ff70042fa873b5736d7146e926-4e5bd857642c176a0631f80386aed6e8:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW-bBHoVZ6JasUiyfqjoHviZK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kCCA6PwDVu4AvJ9HCYKTcW">
#         <div id="ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW-LoSmKEvnycgQV67DZV4oJT" class="ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Without Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/557e0d99e00de97205d3eccaeccfc92b-695036be44364261ea0107ba7c4476f3:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW-LoSmKEvnycgQV67DZV4oJT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-kCCA6PwDVu4AvJ9HCYKTcW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kCCA6PwDVu4AvJ9HCYKTcW {
#             width: 512px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW {
#             width: 512px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW img {
#             width: 512px;
#         }
#
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kCCA6PwDVu4AvJ9HCYKTcW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-