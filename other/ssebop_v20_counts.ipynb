# %%
from datetime import timedelta, datetime
import pprint

import ee
from IPython.display import Image, display
import ipyplot
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import openet.core

ee.Initialize()

# %%
monthly_coll = ee.ImageCollection('projects/openet/assets/ssebop/conus/gridmet/monthly/v2_0')
band_name = 'et'

years = list(range(2000, 2026))

region = ee.Geometry.BBox(-125.5, 25, -85.5, 50)
#region = ee.Geometry.BBox(-125.0, 25, -86.0, 50)

image_size = 400

et_palette = ['DEC29B', 'E6CDA1', 'EDD9A6', 'F5E4A9', 'FFF4AD', 'C3E683', '6BCC5C', '3BB369', '20998F', '1C8691', '16678A', '114982', '0B2C7A']
viridis = ['440154', '433982', '30678D', '218F8B', '36B677', '8ED542', 'FDE725']
# et_vis = {min: 0, max: 150, palette: et_palette}

land_mask = ee.Image('projects/openet/assets/features/water_mask').Not()
# Apply the NLCD/NALCMS water mask (anywhere it is water, set the ocean mask 
land_mask = land_mask.where(ee.Image("USGS/NLCD_RELEASES/2020_REL/NALCMS").unmask(18).eq(18), 0)
# land_mask = land_mask.And(ee.Image("USGS/NLCD_RELEASES/2020_REL/NALCMS").unmask(18).neq(18))
# # land_mask = ee.Image('projects/openet/assets/meteorology/conus404/ancillary/land_mask')

# %%
def mask_count_zero(img):
    mask_img = img.select(['count']).gt(0)
    return img.updateMask(mask_img)

# %%
year = 2022
image_url = (
    monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 500})
)
Image(image_url, embed=True, format='png')

# %%
year = 2022
image_url = (
    monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 450})
)
Image(image_url, embed=True, format='png')

# %%
year = 2022
image_url = (
    monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').map(mask_count_zero).select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 450})
)
Image(image_url, embed=True, format='png')

# %%
year = 2012
image_url = (
    monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 450})
)
Image(image_url, embed=True, format='png')

# %%
year = 2012
image_url = (
    monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').map(mask_count_zero).select([band_name]).count()
    .visualize(min=0, max=12, palette=viridis)
    .getThumbURL({'region': region, 'dimensions': 450})
)
Image(image_url, embed=True, format='png')

# %%
for year in years:
    print(year)
    with_count_zero_url = (
        monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').select([band_name]).count()
        .visualize(min=0, max=12, palette=viridis)
        .getThumbURL({'region': region, 'dimensions': image_size})
    )
    no_count_zero_url = (
        monthly_coll.filterDate(f'{year}-01-01', f'{year+1}-01-01').map(mask_count_zero).select([band_name]).count()
        .visualize(min=0, max=12, palette=viridis)
        .getThumbURL({'region': region, 'dimensions': image_size})
    )
    ipyplot.plot_images([with_count_zero_url, no_count_zero_url], labels=['With Count Zero Months', 'Without Count Zero Months'], show_url=False, img_width=image_size)
    #break
# Out:
# 2000
#     <style>
#         #ipyplot-html-viewer-toggle-fvf6DXvUivwghdNS2zTknV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fvf6DXvUivwghdNS2zTknV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fvf6DXvUivwghdNS2zTknV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fvf6DXvUivwghdNS2zTknV:checked ~ #ipyplot-html-viewer-textarea-fvf6DXvUivwghdNS2zTknV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fvf6DXvUivwghdNS2zTknV:checked + #ipyplot-html-viewer-label-fvf6DXvUivwghdNS2zTknV:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-fvf6DXvUivwghdNS2zTknV">
#         <label id="ipyplot-html-viewer-label-fvf6DXvUivwghdNS2zTknV" for="ipyplot-html-viewer-toggle-fvf6DXvUivwghdNS2zTknV">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-fvf6DXvUivwghdNS2zTknV" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-N86hwwCCttLYYEv87Ramma {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-N86hwwCCttLYYEv87Ramma {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-N86hwwCCttLYYEv87Ramma {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-N86hwwCCttLYYEv87Ramma span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-N86hwwCCttLYYEv87Ramma span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-N86hwwCCttLYYEv87Ramma img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-N86hwwCCttLYYEv87Ramma span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-N86hwwCCttLYYEv87Ramma span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-N86hwwCCttLYYEv87Ramma]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-N86hwwCCttLYYEv87Ramma]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div
getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-BVJTQEt5UTRBqs2ea3fhVu-UzYtUBaCCfrviLMkJMGeRx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 2003
#     <style>
#         #ipyplot-html-viewer-toggle-NqafFr56V4f8NHii3bNCre {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-NqafFr56V4f8NHii3bNCre {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-NqafFr56V4f8NHii3bNCre {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-NqafFr56V4f8NHii3bNCre:checked ~ #ipyplot-html-viewer-textarea-NqafFr56V4f8NHii3bNCre {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-NqafFr56V4f8NHii3bNCre:checked + #ipyplot-html-viewer-label-NqafFr56V4f8NHii3bNCre:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-NqafFr56V4f8NHii3bNCre">
#         <label id="ipyplot-html-viewer-label-NqafFr56V4f8NHii3bNCre" for="ipyplot-html-viewer-toggle-NqafFr56V4f8NHii3bNCre">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-NqafFr56V4f8NHii3bNCre" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-JmfAvpGQajjLRHa2LdBD6p {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-JmfAvpGQajjLRHa2LdBD6p {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-JmfAvpGQajjLRHa2LdBD6p">
#     <div class="ipyplot-placeholder-div-JmfAvpGQajjLRHa2LdBD6p">
#         <div id="ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p-Fob2wcMuG5zLwv2Xmm5x59" class="ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p">
#             <h4 style="font-size: 12px; word-wrap: break-word;">With Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/0a694529cfe560b43fac51e4074f9b53-0481b8787d855e1511d6982204e42d58:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p-Fob2wcMuG5zLwv2Xmm5x59">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JmfAvpGQajjLRHa2LdBD6p">
#         <div id="ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p-8j5hkXuDc5y65YcJAh9zgD" class="ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Without Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/c63d9a417f33bb942fa391ab7c54b148-a41e38e509fdee4664ebca8698588f99:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p-8j5hkXuDc5y65YcJAh9zgD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-JmfAvpGQajjLRHa2LdBD6p {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-JmfAvpGQajjLRHa2LdBD6p {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-JmfAvpGQajjLRHa2LdBD6p">
#     <div class="ipyplot-placeholder-div-JmfAvpGQajjLRHa2LdBD6p">
#         <div id="ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p-Fob2wcMuG5zLwv2Xmm5x59" class="ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p">
#             <h4 style="font-size: 12px; word-wrap: break-word;">With Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/0a694529cfe560b43fac51e4074f9b53-0481b8787d855e1511d6982204e42d58:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p-Fob2wcMuG5zLwv2Xmm5x59">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JmfAvpGQajjLRHa2LdBD6p">
#         <div id="ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p-8j5hkXuDc5y65YcJAh9zgD" class="ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Without Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/c63d9a417f33bb942fa391ab7c54b148-a41e38e509fdee4664ebca8698588f99:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JmfAvpGQajjLRHa2LdBD6p-8j5hkXuDc5y65YcJAh9zgD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 2004
#     <style>
#         #ipyplot-html-viewer-toggle-kkbMc6GQKdumTJpfL9DeE2 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kkbMc6GQKdumTJpfL9DeE2 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kkbMc6GQKdumTJpfL9DeE2 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kkbMc6GQKdumTJpfL9DeE2:checked ~ #ipyplot-html-viewer-textarea-kkbMc6GQKdumTJpfL9DeE2 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kkbMc6GQKdumTJpfL9DeE2:checked + #ipyplot-html-viewer-label-kkbMc6GQKdumTJpfL9DeE2:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-kkbMc6GQKdumTJpfL9DeE2">
#         <label id="ipyplot-html-viewer-label-kkbMc6GQKdumTJpfL9DeE2" for="ipyplot-html-viewer-toggle-kkbMc6GQKdumTJpfL9DeE2">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-kkbMc6GQKdumTJpfL9DeE2" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-ZbtcbhzCz6hD8CBvuQM7Gi {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ZbtcbhzCz6hD8CBvuQM7Gi {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ZbtcbhzCz6hD8CBvuQM7Gi">
#     <div class="ipyplot-placeholder-div-ZbtcbhzCz6hD8CBvuQM7Gi">
#         <div id="ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi-EcTJQ9NqoWS6tPResvEL8n" class="ipyplot-content-div-ZbtcbhzCz6hD8CBvuQM7Gi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">With Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/
getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM-GDGtAyrQSvnzaZbGskk5Nt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-LyZDPxMqDpBL76BSSCNhFM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LyZDPxMqDpBL76BSSCNhFM {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LyZDPxMqDpBL76BSSCNhFM">
#     <div class="ipyplot-placeholder-div-LyZDPxMqDpBL76BSSCNhFM">
#         <div id="ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM-Hr5aqpnqNyXf9zyfKi2LSd" class="ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">With Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/c960dbc94abe57c921b89b37872fe2cd-6af1aa547a193a6c09acc8a9bf1c495c:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM-Hr5aqpnqNyXf9zyfKi2LSd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LyZDPxMqDpBL76BSSCNhFM">
#         <div id="ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM-GDGtAyrQSvnzaZbGskk5Nt" class="ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Without Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/05d7149ae8f5356b03877f5a52fb3740-1599d301a1166ac33ce7a9f88c6ca821:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LyZDPxMqDpBL76BSSCNhFM-GDGtAyrQSvnzaZbGskk5Nt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 2025
#     <style>
#         #ipyplot-html-viewer-toggle-4Bs2VtRB8RhFqqdmqjo9DC {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4Bs2VtRB8RhFqqdmqjo9DC {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4Bs2VtRB8RhFqqdmqjo9DC {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4Bs2VtRB8RhFqqdmqjo9DC:checked ~ #ipyplot-html-viewer-textarea-4Bs2VtRB8RhFqqdmqjo9DC {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4Bs2VtRB8RhFqqdmqjo9DC:checked + #ipyplot-html-viewer-label-4Bs2VtRB8RhFqqdmqjo9DC:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-4Bs2VtRB8RhFqqdmqjo9DC">
#         <label id="ipyplot-html-viewer-label-4Bs2VtRB8RhFqqdmqjo9DC" for="ipyplot-html-viewer-toggle-4Bs2VtRB8RhFqqdmqjo9DC">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-4Bs2VtRB8RhFqqdmqjo9DC" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-dGMYsZnysf5AmcNnpbvkvp {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dGMYsZnysf5AmcNnpbvkvp {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-dGMYsZnysf5AmcNnpbvkvp">
#     <div class="ipyplot-placeholder-div-dGMYsZnysf5AmcNnpbvkvp">
#         <div id="ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp-daSpE7UgJpkhxWiBt9YNiR" class="ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">With Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/f0e3d0b8f2938795e2cdfd3810f0900c-d6ab02813fde1c357a59316abcb97026:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp-daSpE7UgJpkhxWiBt9YNiR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dGMYsZnysf5AmcNnpbvkvp">
#         <div id="ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp-4ogHFFFbXyLsr5mSeZ8gyr" class="ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Without Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/c1e35f8addc43bae15e02bc66a7e3486-b74a1d9735f8ec7e397a93a46ab81475:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp-4ogHFFFbXyLsr5mSeZ8gyr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-dGMYsZnysf5AmcNnpbvkvp {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dGMYsZnysf5AmcNnpbvkvp {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-dGMYsZnysf5AmcNnpbvkvp">
#     <div class="ipyplot-placeholder-div-dGMYsZnysf5AmcNnpbvkvp">
#         <div id="ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp-daSpE7UgJpkhxWiBt9YNiR" class="ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">With Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/f0e3d0b8f2938795e2cdfd3810f0900c-d6ab02813fde1c357a59316abcb97026:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp-daSpE7UgJpkhxWiBt9YNiR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dGMYsZnysf5AmcNnpbvkvp">
#         <div id="ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp-4ogHFFFbXyLsr5mSeZ8gyr" class="ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Without Count Zero Months</h4>
#             <img src="https://earthengine.googleapis.com/v1/projects/openet/thumbnails/c1e35f8addc43bae15e02bc66a7e3486-b74a1d9735f8ec7e397a93a46ab81475:getPixels"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dGMYsZnysf5AmcNnpbvkvp-4ogHFFFbXyLsr5mSeZ8gyr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
