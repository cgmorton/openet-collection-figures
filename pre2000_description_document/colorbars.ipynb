# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# %matplotlib inline

# %%
min_val = 0
max_val = 12

# Create some dummy data and a colormap for the colorbar
fig, ax = plt.subplots(figsize=(3, 0.2)) # Adjust figsize for desired dimensions
# fig.subplots_adjust(bottom=0.5) # Adjust spacing if needed

ticks = list(range(0, max_val+1))
boundaries = np.linspace(min_val-0.5, max_val+0.5, max_val-min_val+2)
cmap = plt.get_cmap('viridis')
norm = mcolors.BoundaryNorm(boundaries, cmap.N)
cbar = fig.colorbar(
    plt.cm.ScalarMappable(norm=norm, cmap=cmap),
    cax=ax,
    orientation='horizontal',
    ticks=ticks,
)
cbar.set_label('Monthly Image Count', size=9)
cbar.ax.minorticks_off()
cbar.ax.tick_params(labelsize=9)

# fig.savefig('horizontal_colorbar.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
min_val = 0
max_val = 4

fig, ax = plt.subplots(figsize=(1.4, 0.2)) # Adjust figsize for desired dimensions
#fig.subplots_adjust(bottom=0.4) # Adjust spacing if needed

ticks = list(range(0, max_val+1))
boundaries = np.linspace(min_val-0.5, max_val+0.5, max_val-min_val+2)
cmap = plt.get_cmap('viridis')
norm = mcolors.BoundaryNorm(boundaries, cmap.N)
cbar = fig.colorbar(
    plt.cm.ScalarMappable(norm=norm, cmap=cmap),
    cax=ax,
    orientation='horizontal',
    label='Images per Month',
    ticks=ticks,
)
cbar.set_label('Images per Month', size=9)
cbar.ax.minorticks_off()
cbar.ax.tick_params(labelsize=9)

# fig.savefig('horizontal_colorbar.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
min_val = 0
max_val = 12

fig, ax = plt.subplots(figsize=(3, 0.2)) # Adjust figsize for desired dimensions
# fig.subplots_adjust(bottom=0.5) # Adjust spacing if needed

ticks = list(range(0, max_val+1))
#boundaries = np.linspace(min_val-0.5, max_val+0.5, max_val-min_val+2)
cmap = plt.get_cmap('viridis')
norm = mcolors.Normalize(vmin=min_val, vmax=max_val)
#norm = mcolors.BoundaryNorm(boundaries, cmap.N)
cbar = fig.colorbar(
    plt.cm.ScalarMappable(norm=norm, cmap=cmap),
    cax=ax,
    orientation='horizontal',
    ticks=ticks,
)
cbar.set_label('Monthly Image Count', size=9)
cbar.ax.minorticks_off()
cbar.ax.tick_params(labelsize=9)

# fig.savefig('horizontal_colorbar.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
min_val = 0
max_val = 4

fig, ax = plt.subplots(figsize=(1.4, 0.2)) # Adjust figsize for desired dimensions
# fig.subplots_adjust(bottom=0.5) # Adjust spacing if needed

ticks = list(range(0, max_val+1))
#boundaries = np.linspace(min_val-0.5, max_val+0.5, max_val-min_val+2)
cmap = plt.get_cmap('viridis')
norm = mcolors.Normalize(vmin=min_val, vmax=max_val)
#norm = mcolors.BoundaryNorm(boundaries, cmap.N)
cbar = fig.colorbar(
    plt.cm.ScalarMappable(norm=norm, cmap=cmap),
    cax=ax,
    orientation='horizontal',
    ticks=ticks,
)
cbar.set_label('Images per Month', size=9)
cbar.ax.minorticks_off()
cbar.ax.tick_params(labelsize=9)

# fig.savefig('horizontal_colorbar.png', dpi=300, bbox_inches='tight')
plt.show()
